# %%
# %cd C:/Users/sylee/Documents/GitHub/Final_2Kyoungh/data
# Out:
# C:\Users\sylee\Documents\GitHub\Final_2Kyoungh\data

# %%
import requests
import json
import pandas as pd

## 기본 세팅 부분
##종웅님 
headers = {"X-Naver-Client-Id": "EmdlUXsc4CuKNm_kxYKS",
           "X-Naver-Client-Secret":"dSLoIEmMgy"}

url = "https://openapi.naver.com/v1/datalab/shopping/categories"
def change_index(df, column_name):
    df = df.set_index("period")
    df.columns = [column_name]
    return df

# %%
devices=['','pc','mo']

## 대분류 카테고리 설정
for i in devices:
    categories = [
          {"name": "간편조리식품", "param": [ "50000026"]},
          {"name": "김치", "param": [ "50000147"]},
          {"name": "농산물", "param": [ "50000160"]},
          {"name": "반찬", "param": [ "50000147"]},
          {"name": "수산물", "param": [ "50000159"]},
          {"name": "음료", "param": [ "50000148"]},
          {"name": "축산물", "param": [ "50000116"]}
      ]
## API 요청 값 작성, 디지털/가전 = result[0], 패션의류 = result[1]
    data = {
    "startDate": "2021-05-10",
    "endDate": "2023-07-03",
    "timeUnit": "date",
    "category": [
        {"name": "식품", "param": [ "50000006"]},
        {"name": "건강식품", "param": [ "50000030"]},
    ],
    "device":i,
    "gender":"",
    "ages":[]
    }
## 데이터 정제 및 merge 파트
    response = requests.post(url, headers=headers, json=data)

    results = response.json()["results"]


    df_1 = change_index(pd.DataFrame(results[0]["data"]), "식품")
    df_2 = change_index(pd.DataFrame(results[1]["data"]), "건강식품")
##
    df_all_i = pd.merge(df_1, df_2, left_on="period", right_on="period")
## 반복문 통해서 카테고리에 설정된 값, 불러오고 저장, 합치기
    for category in categories:
        if len(data["category"]) > 2:
            data["category"].pop(2)
        data["category"].append(category)

        result = requests.post(url, headers=headers, json=data)

        results = result.json()["results"]

        df = change_index(pd.DataFrame(results[2]["data"]), category["name"])

        df_all_i = pd.merge(df_all_i, df, left_on="period", right_on="period")
    if i == "":
        df_all_1 = df_all_i
        df_all_1['유형']='PC+MO'
        df_all_1['성별']='전체'
        df_all_1['연령']='전체'
    if i == "pc":
        df_all_2 = df_all_i
        df_all_2['유형']='PC'
        df_all_2['성별']='전체'
        df_all_2['연령']='전체'
    if i == "mo":
        df_all_3 = df_all_i
        df_all_3['유형']='MO'
        df_all_3['성별']='전체'
        df_all_3['연령']='전체'
##    
df_list=[df_all_1,df_all_2,df_all_3]
df_all_a=pd.concat(df_list)
df_all_a.drop(["식품"], axis=1, inplace=True)
df_all_a
# Out:
#                건강식품   간편조리식품       김치      농산물       반찬      수산물       음료  \
# period
# 2021-05-10  0.67684  0.56467  0.12903  1.06204  0.12903  0.57227  1.41854
# 2021-05-11  0.62994  0.51511  0.11591  0.98023  0.11591  0.54191  1.34287
# 2021-05-12  0.59334  0.48367  0.11844  0.93441  0.11844  0.55589  1.30079
# 2021-05-13  0.56443  0.44275  0.11434  1.01751  0.11434  0.55153  1.22452
# 2021-05-14  0.51820  0.37545  0.09036  0.80112  0.09036  0.45346  1.14186
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-06-29  0.35468  0.62825  0.14086  1.02216  0.14086  0.53653  1.20379
# 2023-06-30  0.32682  0.49155  0.12114  0.82458  0.12114  0.43773  1.04446
# 2023-07-01  0.35338  0.49332  0.13083  0.88965  0.13083  0.42716  1.16334
# 2023-07-02  0.43262  0.60503  0.14713  1.05429  0.14713  0.46099  1.36425
# 2023-07-03  0.40857  0.68165  0.14859  1.08357  0.14859  0.50536  1.42335
#
#                 축산물     유형  성별  연령
# period
# 2021-05-10  0.12073  PC+MO  전체  전체
# 2021-05-11  0.10028  PC+MO  전체  전체
# 2021-05-12  0.09427  PC+MO  전체  전체
# 2021-05-13  0.08965  PC+MO  전체  전체
# 2021-05-14  0.07736  PC+MO  전체  전체
# ...             ...    ...  ..  ..
# 2023-06-29  0.07442     MO  전체  전체
# 2023-06-30  0.06440     MO  전체  전체
# 2023-07-01  0.06891     MO  전체  전체
# 2023-07-02  0.07519     MO  전체  전체
# 2023-07-03  0.09005     MO  전체  전체
#
# [2355 rows x 11 columns]

# %%
devices=['','pc','mo']

## 대분류 카테고리 설정
for i in devices:
    categories = [
          {"name": "간편조리식품", "param": [ "50000026"]},
          {"name": "김치", "param": [ "50000147"]},
          {"name": "농산물", "param": [ "50000160"]},
          {"name": "반찬", "param": [ "50000147"]},
          {"name": "수산물", "param": [ "50000159"]},
          {"name": "음료", "param": [ "50000148"]},
          {"name": "축산물", "param": [ "50000116"]}
      ]
## API 요청 값 작성, 디지털/가전 = result[0], 패션의류 = result[1]
    data = {
    "startDate": "2021-05-10",
    "endDate": "2023-07-03",
    "timeUnit": "date",
    "category": [
        {"name": "식품", "param": [ "50000006"]},
        {"name": "건강식품", "param": [ "50000030"]},
    ],
    "device":i,
    "gender":"f",
    "ages":[]
    }
## 데이터 정제 및 merge 파트
    response = requests.post(url, headers=headers, json=data)

    results = response.json()["results"]


    df_1 = change_index(pd.DataFrame(results[0]["data"]), "식품")
    df_2 = change_index(pd.DataFrame(results[1]["data"]), "건강식품")
##
    df_all_i = pd.merge(df_1, df_2, left_on="period", right_on="period")
## 반복문 통해서 카테고리에 설정된 값, 불러오고 저장, 합치기
    for category in categories:
        if len(data["category"]) > 2:
            data["category"].pop(2)
        data["category"].append(category)

        result = requests.post(url, headers=headers, json=data)

        results = result.json()["results"]

        df = change_index(pd.DataFrame(results[2]["data"]), category["name"])

        df_all_i = pd.merge(df_all_i, df, left_on="period", right_on="period")
    if i == "":
        df_all_1 = df_all_i
        df_all_1['유형']='PC+MO'
        df_all_1['성별']='여성'
        df_all_1['연령']='전체'
    if i == "pc":
        df_all_2 = df_all_i
        df_all_2['유형']='PC'
        df_all_2['성별']='여성'
        df_all_2['연령']='전체'
    if i == "mo":
        df_all_3 = df_all_i
        df_all_3['유형']='MO'
        df_all_3['성별']='여성'
        df_all_3['연령']='전체'
##    
df_list=[df_all_1,df_all_2,df_all_3]
df_all_b=pd.concat(df_list)
df_all_b.drop(["식품"], axis=1, inplace=True)
df_all_b
# Out:
#                건강식품   간편조리식품       김치      농산물       반찬      수산물       음료  \
# period
# 2021-05-10  0.80400  1.14459  0.26289  2.23990  0.26289  0.98838  2.67461
# 2021-05-11  0.75089  1.02330  0.23641  2.05138  0.23641  0.93214  2.52429
# 2021-05-12  0.69054  0.97107  0.23955  1.95079  0.23955  0.94026  2.42278
# 2021-05-13  0.66385  0.86977  0.22714  2.16272  0.22714  0.90995  2.24365
# 2021-05-14  0.59909  0.72990  0.18201  1.65002  0.18201  0.76046  2.00188
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-06-29  0.49376  1.40772  0.31823  2.44328  0.31823  1.06825  2.68538
# 2023-06-30  0.46347  1.10081  0.26642  1.94681  0.26642  0.85944  2.30331
# 2023-07-01  0.50720  1.09503  0.29260  2.10142  0.29260  0.83937  2.54180
# 2023-07-02  0.59205  1.33167  0.32801  2.44679  0.32801  0.90489  2.98782
# 2023-07-03  0.53548  1.55432  0.34010  2.54105  0.34010  0.99086  3.10840
#
#                 축산물     유형  성별  연령
# period
# 2021-05-10  0.30976  PC+MO  여성  전체
# 2021-05-11  0.25411  PC+MO  여성  전체
# 2021-05-12  0.23268  PC+MO  여성  전체
# 2021-05-13  0.22429  PC+MO  여성  전체
# 2021-05-14  0.19179  PC+MO  여성  전체
# ...             ...    ...  ..  ..
# 2023-06-29  0.20334     MO  여성  전체
# 2023-06-30  0.17783     MO  여성  전체
# 2023-07-01  0.18087     MO  여성  전체
# 2023-07-02  0.20009     MO  여성  전체
# 2023-07-03  0.25519     MO  여성  전체
#
# [2355 rows x 11 columns]

# %%
devices=['','pc','mo']

## 대분류 카테고리 설정
for i in devices:
    categories = [
          {"name": "간편조리식품", "param": [ "50000026"]},
          {"name": "김치", "param": [ "50000147"]},
          {"name": "농산물", "param": [ "50000160"]},
          {"name": "반찬", "param": [ "50000147"]},
          {"name": "수산물", "param": [ "50000159"]},
          {"name": "음료", "param": [ "50000148"]},
          {"name": "축산물", "param": [ "50000116"]}
      ]
## API 요청 값 작성, 디지털/가전 = result[0], 패션의류 = result[1]
    data = {
    "startDate": "2021-05-10",
    "endDate": "2023-07-03",
    "timeUnit": "date",
    "category": [
        {"name": "식품", "param": [ "50000006"]},
        {"name": "건강식품", "param": [ "50000030"]},
    ],
    "device":i,
    "gender":"m",
    "ages":[]
    }
## 데이터 정제 및 merge 파트
    response = requests.post(url, headers=headers, json=data)

    results = response.json()["results"]


    df_1 = change_index(pd.DataFrame(results[0]["data"]), "식품")
    df_2 = change_index(pd.DataFrame(results[1]["data"]), "건강식품")
##
    df_all_i = pd.merge(df_1, df_2, left_on="period", right_on="period")
## 반복문 통해서 카테고리에 설정된 값, 불러오고 저장, 합치기
    for category in categories:
        if len(data["category"]) > 2:
            data["category"].pop(2)
        data["category"].append(category)

        result = requests.post(url, headers=headers, json=data)

        results = result.json()["results"]

        df = change_index(pd.DataFrame(results[2]["data"]), category["name"])

        df_all_i = pd.merge(df_all_i, df, left_on="period", right_on="period")
    if i == "":
        df_all_1 = df_all_i
        df_all_1['유형']='PC+MO'
        df_all_1['성별']='남성'
        df_all_1['연령']='전체'
    if i == "pc":
        df_all_2 = df_all_i
        df_all_2['유형']='PC'
        df_all_2['성별']='남성'
        df_all_2['연령']='전체'
    if i == "mo":
        df_all_3 = df_all_i
        df_all_3['유형']='MO'
        df_all_3['성별']='남성'
        df_all_3['연령']='전체'
##    
df_list=[df_all_1,df_all_2,df_all_3]
df_all_c=pd.concat(df_list)
df_all_c.drop(["식품"], axis=1, inplace=True)
df_all_c
# Out:
#                건강식품   간편조리식품       김치      농산물       반찬      수산물       음료  \
# period
# 2021-05-10  5.25190  2.50616  0.51872  4.18303  0.51872  3.32231  6.19389
# 2021-05-11  4.80560  2.26150  0.44831  3.84559  0.44831  3.12470  5.78865
# 2021-05-12  4.52646  2.10371  0.44636  3.66112  0.44636  3.26023  5.65136
# 2021-05-13  4.27107  1.97670  0.45814  3.92503  0.45814  3.23752  5.32907
# 2021-05-14  3.87031  1.65871  0.33080  3.03269  0.33080  2.56778  4.69102
# ...             ...      ...      ...      ...      ...      ...      ...
# 2023-06-29  3.22065  3.45304  0.64522  4.77655  0.64522  3.67240  6.48814
# 2023-06-30  2.96091  2.81177  0.53051  4.01402  0.53051  3.04272  5.74816
# 2023-07-01  3.28798  2.89198  0.61993  4.52245  0.61993  3.09360  6.63766
# 2023-07-02  3.94692  3.63204  0.73365  5.36869  0.73365  3.25149  7.74226
# 2023-07-03  3.59349  3.80928  0.69092  5.32710  0.69092  3.55549  8.11679
#
#                 축산물     유형  성별  연령
# period
# 2021-05-10  0.31505  PC+MO  남성  전체
# 2021-05-11  0.24608  PC+MO  남성  전체
# 2021-05-12  0.24036  PC+MO  남성  전체
# 2021-05-13  0.21947  PC+MO  남성  전체
# 2021-05-14  0.20080  PC+MO  남성  전체
# ...             ...    ...  ..  ..
# 2023-06-29  0.24313     MO  남성  전체
# 2023-06-30  0.21045     MO  남성  전체
# 2023-07-01  0.28814     MO  남성  전체
# 2023-07-02  0.30817     MO  남성  전체
# 2023-07-03  0.29264     MO  남성  전체
#
# [2355 rows x 11 columns]

# %%
df_list=[df_all_a,df_all_b,df_all_c]
df_all=pd.concat(df_list)

## 엑셀에 저장
df_all.to_excel("MCLS_07_all_fm_all.xlsx", sheet_name="click ratio")
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7065 entries, 2021-05-10 to 2023-07-03
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   건강식품    7065 non-null   float64
#  1   간편조리식품  7065 non-null   float64
#  2   김치      7065 non-null   float64
#  3   농산물     7065 non-null   float64
#  4   반찬      7065 non-null   float64
#  5   수산물     7065 non-null   float64
#  6   음료      7065 non-null   float64
#  7   축산물     7065 non-null   float64
#  8   유형      7065 non-null   object
#  9   성별      7065 non-null   object
#  10  연령      7065 non-null   object
# dtypes: float64(8), object(3)
# memory usage: 662.3+ KB
